# %% [markdown]
# ## Problem Statement
# We are going to classify the delays in domestic flights using the dataset from the month of February that is made publicly available by the Bureau of Transportation Statistics, Govt of USA.
#
# We are going to use *logistic regrssion* as the primary classifier but as we go along we'll also use *SVM* and *Neural Networks* based on the accuracy of the predictor!

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import OneHotEncoder, LabelEncoder

# %%
df = pd.read_csv("Feb_2020_ontime.csv")

# %%
df.head()
# Out:
#    DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER  OP_CARRIER_AIRLINE_ID  \
# 0             1            6                MQ                  20398
# 1             1            6                MQ                  20398
# 2             1            6                MQ                  20398
# 3             1            6                MQ                  20398
# 4             1            6                MQ                  20398
#
#   OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# 0         MQ   N269NN               3825              13930
# 1         MQ   N908AE               3829              12478
# 2         MQ   N663AR               3831              11953
# 3         MQ   N618AE               3833              11298
# 4         MQ   N618AE               3833              14842
#
#    ORIGIN_AIRPORT_SEQ_ID ORIGIN  ...  DEST  DEP_TIME DEP_DEL15  DEP_TIME_BLK  \
# 0                1393007    ORD  ...   TUL    1646.0       0.0     1600-1659
# 1                1247805    JFK  ...   BNA    1336.0       0.0     1300-1359
# 2                1195302    GNV  ...   MIA     844.0       0.0     0800-0859
# 3                1129806    DFW  ...   SJT     852.0       0.0     0800-0859
# 4                1484202    SJT  ...   DFW    1024.0       0.0     1000-1059
#
#    ARR_TIME ARR_DEL15  CANCELLED  DIVERTED  DISTANCE  Unnamed: 21
# 0    1820.0       0.0        0.0       0.0     585.0          NaN
# 1    1458.0       0.0        0.0       0.0     765.0          NaN
# 2    1020.0       1.0        0.0       0.0     294.0          NaN
# 3     955.0       0.0        0.0       0.0     229.0          NaN
# 4    1132.0       0.0        0.0       0.0     229.0          NaN
#
# [5 rows x 22 columns]

# %%
#Let's go ahead and delete the last column in dataset
df.drop("Unnamed: 21", axis = 1, inplace = True)
#Let's check for the columns name and understand what we can work with 
df.columns
# Out:
# Index(['DAY_OF_MONTH', 'DAY_OF_WEEK', 'OP_UNIQUE_CARRIER',
#        'OP_CARRIER_AIRLINE_ID', 'OP_CARRIER', 'TAIL_NUM', 'OP_CARRIER_FL_NUM',
#        'ORIGIN_AIRPORT_ID', 'ORIGIN_AIRPORT_SEQ_ID', 'ORIGIN',
#        'DEST_AIRPORT_ID', 'DEST_AIRPORT_SEQ_ID', 'DEST', 'DEP_TIME',
#        'DEP_DEL15', 'DEP_TIME_BLK', 'ARR_TIME', 'ARR_DEL15', 'CANCELLED',
#        'DIVERTED', 'DISTANCE'],
#       dtype='object')

# %%
# let's explore a bit more and understand what some of these columns represent 
df['OP_UNIQUE_CARRIER'].unique()
# Out:
# array(['MQ', 'B6', 'OH', 'AA', 'NK', 'YX', 'F9', 'DL', 'YV', 'EV', 'HA',
#        '9E', 'G4', 'UA', 'AS', 'WN', 'OO'], dtype=object)

# %%
df['OP_CARRIER_AIRLINE_ID'].unique()
# Out:
# array([20398, 20409, 20397, 19805, 20416, 20452, 20436, 19790, 20378,
#        20366, 19690, 20363, 20368, 19977, 19930, 19393, 20304])

# %%
df['OP_CARRIER'].unique()
# Out:
# array(['MQ', 'B6', 'OH', 'AA', 'NK', 'YX', 'F9', 'DL', 'YV', 'EV', 'HA',
#        '9E', 'G4', 'UA', 'AS', 'WN', 'OO'], dtype=object)

# %% [markdown]
# In our case, **OP_UNIQUE_CARRIER, OP_CARRIER and OP_CARRIER_AIRLINE_ID** all kind of means the same thing. Those are codes assinged by the DOT to identify individual carriers.
#
# For our analysis let's use just **OP_CARRIER** and drop the other two columns.
#
# Also, let's remove the **TAIL_NUM AND OP_CARRIER_FL_NUM** from our dataset.

# %%
df.drop(['OP_UNIQUE_CARRIER','OP_CARRIER_AIRLINE_ID','TAIL_NUM','OP_CARRIER_FL_NUM','DIVERTED'], axis = 1, inplace = True)

# %%
#Checking for nulll values before moving forward 
df.isna().sum()
# Out:
# DAY_OF_MONTH                0
# DAY_OF_WEEK                 0
# OP_CARRIER                  0
# ORIGIN_AIRPORT_ID           0
# ORIGIN_AIRPORT_SEQ_ID       0
# ORIGIN                      0
# DEST_AIRPORT_ID             0
# DEST_AIRPORT_SEQ_ID         0
# DEST                        0
# DEP_TIME                 4938
# DEP_DEL15                4951
# DEP_TIME_BLK                0
# ARR_TIME                 5287
# ARR_DEL15                6192
# CANCELLED                   0
# DISTANCE                    0
# dtype: int64

# %%
# Let's go ahead and drop all the null values and store it in a new dataframe for ease of computation
df1 = df.fillna(method = 'ffill')

# %% [markdown]
# Now let's use the `describe` function to see how our data looks.

# %%
df1.describe()
# Out:
#         DAY_OF_MONTH    DAY_OF_WEEK  ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID  \
# count  574268.000000  574268.000000      574268.000000           5.742680e+05
# mean       15.179477       3.989280       12658.021716           1.265806e+06
# std         8.295999       1.988345        1524.563452           1.524561e+05
# min         1.000000       1.000000       10135.000000           1.013506e+06
# 25%         8.000000       2.000000       11292.000000           1.129202e+06
# 50%        15.000000       4.000000       12889.000000           1.288903e+06
# 75%        22.000000       6.000000       14027.000000           1.402702e+06
# max        29.000000       7.000000       16869.000000           1.686901e+06
#
#        DEST_AIRPORT_ID  DEST_AIRPORT_SEQ_ID       DEP_TIME      DEP_DEL15  \
# count    574268.000000         5.742680e+05  574268.000000  574268.000000
# mean      12658.143861         1.265818e+06    1332.908461       0.145885
# std        1524.594853         1.524592e+05     498.981746       0.352991
# min       10135.000000         1.013506e+06       1.000000       0.000000
# 25%       11292.000000         1.129202e+06     918.000000       0.000000
# 50%       12889.000000         1.288903e+06    1328.000000       0.000000
# 75%       14027.000000         1.402702e+06    1741.000000       0.000000
# max       16869.000000         1.686901e+06    2400.000000       1.000000
#
#             ARR_TIME      ARR_DEL15      CANCELLED       DISTANCE
# count  574268.000000  574268.000000  574268.000000  574268.000000
# mean     1478.573748       0.151156       0.008942     795.735522
# std       528.104272       0.358201       0.094138     582.960817
# min         1.000000       0.000000       0.000000      31.000000
# 25%      1058.000000       0.000000       0.000000     369.000000
# 50%      1513.000000       0.000000       0.000000     641.000000
# 75%      1920.000000       0.000000       0.000000    1036.000000
# max      2400.000000       1.000000       1.000000    5095.000000

# %%
#Starting by binning the distance column into four different subgroups 
bin_labels = ['1','2','3','4']
bins_level = [0,400,800,1200,10000] #Including a huge value to include all values above 1200
df1['Binned_Distance_Labels'] = pd.cut(df1['DISTANCE'], bins = bins_level, labels = bin_labels )

# %% [markdown]
# So we have binned the distance column. I have used bin labels to be 1,2,3 and 4 just for the ease of use and it can be easily fit into the model without encoding
#
# For reference, distances from
#
# (0 - 400] miles = 1
#
# (400 - 800] miles = 2
#
# (800 - 1200] miles = 3
#
# (1200 - 10000] miles = 4

# %%
#Now we can drop the distance column
df1.drop(['DISTANCE'], axis = 1, inplace = True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 574268 entries, 0 to 574267
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   DAY_OF_MONTH            574268 non-null  int64
#  1   DAY_OF_WEEK             574268 non-null  int64
#  2   OP_CARRIER              574268 non-null  object
#  3   ORIGIN_AIRPORT_ID       574268 non-null  int64
#  4   ORIGIN_AIRPORT_SEQ_ID   574268 non-null  int64
#  5   ORIGIN                  574268 non-null  object
#  6   DEST_AIRPORT_ID         574268 non-null  int64
#  7   DEST_AIRPORT_SEQ_ID     574268 non-null  int64
#  8   DEST                    574268 non-null  object
#  9   DEP_TIME                574268 non-null  float64
#  10  DEP_DEL15               574268 non-null  float64
#  11  DEP_TIME_BLK            574268 non-null  object
#  12  ARR_TIME                574268 non-null  float64
#  13  ARR_DEL15               574268 non-null  float64
#  14  CANCELLED               574268 non-null  float64
#  15  Binned_Distance_Labels  574268 non-null  category
# dtypes: category(1), float64(5), int64(6), object(4)
# memory usage: 66.3+ MB

# %%
df1.head()
# Out:
#    DAY_OF_MONTH  DAY_OF_WEEK OP_CARRIER  ORIGIN_AIRPORT_ID  \
# 0             1            6         MQ              13930
# 1             1            6         MQ              12478
# 2             1            6         MQ              11953
# 3             1            6         MQ              11298
# 4             1            6         MQ              14842
#
#    ORIGIN_AIRPORT_SEQ_ID ORIGIN  DEST_AIRPORT_ID  DEST_AIRPORT_SEQ_ID DEST  \
# 0                1393007    ORD            15370              1537002  TUL
# 1                1247805    JFK            10693              1069302  BNA
# 2                1195302    GNV            13303              1330303  MIA
# 3                1129806    DFW            14842              1484202  SJT
# 4                1484202    SJT            11298              1129806  DFW
#
#    DEP_TIME  DEP_DEL15 DEP_TIME_BLK  ARR_TIME  ARR_DEL15  CANCELLED  \
# 0    1646.0        0.0    1600-1659    1820.0        0.0        0.0
# 1    1336.0        0.0    1300-1359    1458.0        0.0        0.0
# 2     844.0        0.0    0800-0859    1020.0        1.0        0.0
# 3     852.0        0.0    0800-0859     955.0        0.0        0.0
# 4    1024.0        0.0    1000-1059    1132.0        0.0        0.0
#
#   Binned_Distance_Labels
# 0                      2
# 1                      2
# 2                      1
# 3                      1
# 4                      1

# %%
#Let's check how our target variable is distributed
sns.countplot(x = df1['CANCELLED'],palette= 'copper')

# %% [markdown]
# From the above plot we can see that our data is highly imblanced and we have to use oversampling and undersampling methodologies before we can train the model.
# But before that's let's do some EDA and understand how our regressors affect the target variable.

# %%
fig, ax = plt.subplots(figsize = (20,10))
df2 = df1[['ORIGIN','CANCELLED']].loc[df1['CANCELLED'] == 1].groupby('ORIGIN').count().sort_values(by = 'CANCELLED', ascending = False).reset_index() # Got the values of origins with the overall number of flight cancellations
sns.barplot(x = 'ORIGIN', y = 'CANCELLED', data = df2.head(10), ax = ax, palette = 'copper')

# %% [markdown]
# From the graph above, we can see that a lot of flights from Charlotte have been cancelled in the month of February. This could be due to the hard weather conditions in NC.
#
# We can also understand from the plot that the origin does play a role in deciding if the flight is going to be cancelled or not.

# %%
#moving on, let's see the relationship between Carriers and cancellations. 
df3 = df1[['OP_CARRIER','CANCELLED']].loc[df['CANCELLED']==1].groupby('OP_CARRIER').count().reset_index()
df4 = df1[['OP_CARRIER','CANCELLED']].groupby('OP_CARRIER').count().reset_index()
fig, ax = plt.subplots(1,2,figsize = (30,10))
a = sns.barplot(x = 'OP_CARRIER', y = 'CANCELLED', data = df4, palette = "copper",ax = ax[0])
a.set_xlabel("Carrier")
a.set_ylabel("Total number of flights")
b = sns.barplot(x = 'OP_CARRIER', y = 'CANCELLED', data = df3, palette = 'copper',ax = ax[1])
b.set_xlabel("Carrier")
b.set_ylabel("Total Number of flights cancelled")
# Out:
# Text(0, 0.5, 'Total Number of flights cancelled')

# %% [markdown]
# We can see that Southwest(WN) is associated with large number of flights and also large number of flight cancellations.
#
# Delta on the other hand operates quite a lot of flights but the number of flights cancelled is actually pretty low.

# %%
df5 = df1[['DAY_OF_MONTH','CANCELLED']].loc[df1['CANCELLED']==1].groupby('DAY_OF_MONTH').count().reset_index()
fig = plt.subplots(figsize = (15,10))
sns.barplot(x = 'DAY_OF_MONTH', y = 'CANCELLED', data = df5 , palette = 'copper')
plt.show()

# %% [markdown]
# We can see that the first half of the month has a lot of cancellations and as the month moves on, the number of cancellations actually decreases. Intresting!!

# %%
df6 = df1[['DAY_OF_WEEK','CANCELLED']].loc[df1['CANCELLED']==1].groupby('DAY_OF_WEEK').count().reset_index()
fig = plt.subplots(figsize = (15,10))
sns.barplot(x = 'DAY_OF_WEEK', y = 'CANCELLED', data = df6 , palette = 'copper')
plt.show()

# %% [markdown]
# We can see that Wednesdays have the most cancellations followed by Thursday and Satuday has the third most number of cancellations.

# %%
# Let's see how our columns look like
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 574268 entries, 0 to 574267
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   DAY_OF_MONTH            574268 non-null  int64
#  1   DAY_OF_WEEK             574268 non-null  int64
#  2   OP_CARRIER              574268 non-null  object
#  3   ORIGIN_AIRPORT_ID       574268 non-null  int64
#  4   ORIGIN_AIRPORT_SEQ_ID   574268 non-null  int64
#  5   ORIGIN                  574268 non-null  object
#  6   DEST_AIRPORT_ID         574268 non-null  int64
#  7   DEST_AIRPORT_SEQ_ID     574268 non-null  int64
#  8   DEST                    574268 non-null  object
#  9   DEP_TIME                574268 non-null  float64
#  10  DEP_DEL15               574268 non-null  float64
#  11  DEP_TIME_BLK            574268 non-null  object
#  12  ARR_TIME                574268 non-null  float64
#  13  ARR_DEL15               574268 non-null  float64
#  14  CANCELLED               574268 non-null  float64
#  15  Binned_Distance_Labels  574268 non-null  category
# dtypes: category(1), float64(5), int64(6), object(4)
# memory usage: 66.3+ MB

# %%
df1['Binned_Distance_Labels']=df1['Binned_Distance_Labels'].astype('int') # Converting type to int

# %%
#Now let's encode our Depature time buckets using label encoder 
le = LabelEncoder()
df1['le_encoded_dep_time_bucket'] = pd.DataFrame(le.fit_transform(df1['DEP_TIME_BLK']))#encoding and assinging to a different column

# %%
le1 = LabelEncoder()
df1['le_encoded_origin'] = pd.DataFrame(le1.fit_transform(df1['ORIGIN']))

# %%
le2 = LabelEncoder()
df1['le_encoded_OP_CARRIER'] = pd.DataFrame(le2.fit_transform(df1['OP_CARRIER']))

# %%
df1.head(10)
# Out:
#    DAY_OF_MONTH  DAY_OF_WEEK OP_CARRIER  ORIGIN_AIRPORT_ID  \
# 0             1            6         MQ              13930
# 1             1            6         MQ              12478
# 2             1            6         MQ              11953
# 3             1            6         MQ              11298
# 4             1            6         MQ              14842
# 5             1            6         MQ              13486
# 6             1            6         MQ              14576
# 7             1            6         MQ              11298
# 8             1            6         MQ              10599
# 9             1            6         MQ              13303
#
#    ORIGIN_AIRPORT_SEQ_ID ORIGIN  DEST_AIRPORT_ID  DEST_AIRPORT_SEQ_ID DEST  \
# 0                1393007    ORD            15370              1537002  TUL
# 1                1247805    JFK            10693              1069302  BNA
# 2                1195302    GNV            13303              1330303  MIA
# 3                1129806    DFW            14842              1484202  SJT
# 4                1484202    SJT            11298              1129806  DFW
# 5                1348602    MSO            11298              1129806  DFW
# 6                1457606    ROC            13930              1393007  ORD
# 7                1129806    DFW            14783              1478302  SGF
# 8                1059904    BHM            13303              1330303  MIA
# 9                1330303    MIA            10599              1059904  BHM
#
#    DEP_TIME  DEP_DEL15 DEP_TIME_BLK  ARR_TIME  ARR_DEL15  CANCELLED  \
# 0    1646.0        0.0    1600-1659    1820.0        0.0        0.0
# 1    1336.0        0.0    1300-1359    1458.0        0.0        0.0
# 2     844.0        0.0    0800-0859    1020.0        1.0        0.0
# 3     852.0        0.0    0800-0859     955.0        0.0        0.0
# 4    1024.0        0.0    1000-1059    1132.0        0.0        0.0
# 5     755.0        0.0    0800-0859    1154.0        0.0        0.0
# 6    1122.0        0.0    1100-1159    1211.0        0.0        0.0
# 7    1629.0        0.0    1600-1659    1745.0        0.0        0.0
# 8    1725.0        0.0    1700-1759    2019.0        0.0        0.0
# 9    1552.0        0.0    1600-1659    1653.0        0.0        0.0
#
#    Binned_Distance_Labels  le_encoded_dep_time_bucket  le_encoded_origin  \
# 0                       2                          11                238
# 1                       2                           8                170
# 2                       1                           3                129
# 3                       1                           3                 90
# 4                       1                           5                308
# 5                       4                           3                224
# 6                       2                           6                283
# 7                       1                          11                 90
# 8                       2                          12                 33
# 9                       2                          11                212
#
#    le_encoded_OP_CARRIER
# 0                      9
# 1                      9
# 2                      9
# 3                      9
# 4                      9
# 5                      9
# 6                      9
# 7                      9
# 8                      9
# 9                      9

# %%
df1_updated = df1[['DAY_OF_WEEK','Binned_Distance_Labels','le_encoded_dep_time_bucket','le_encoded_origin','le_encoded_OP_CARRIER','CANCELLED']]
df1_updated.head(10)
# Out:
#    DAY_OF_WEEK  Binned_Distance_Labels  le_encoded_dep_time_bucket  \
# 0            6                       2                          11
# 1            6                       2                           8
# 2            6                       1                           3
# 3            6                       1                           3
# 4            6                       1                           5
# 5            6                       4                           3
# 6            6                       2                           6
# 7            6                       1                          11
# 8            6                       2                          12
# 9            6                       2                          11
#
#    le_encoded_origin  le_encoded_OP_CARRIER  CANCELLED
# 0                238                      9        0.0
# 1                170                      9        0.0
# 2                129                      9        0.0
# 3                 90                      9        0.0
# 4                308                      9        0.0
# 5                224                      9        0.0
# 6                283                      9        0.0
# 7                 90                      9        0.0
# 8                 33                      9        0.0
# 9                212                      9        0.0
